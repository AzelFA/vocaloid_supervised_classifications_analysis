# %% [markdown]
# # Import Library

# %%
import requests
import pandas as pd
import time
import csv
from datetime import datetime

# %% [markdown]
# # Scrape Data

# %% [markdown]
# ## Fetching 25 top rated songs in VocaDB

# %%
def fetch_top_rated_2025(filename="top_rated_2025.csv"):
    url = "https://vocadb.net/api/songs/top-rated"
    params = {
        "durationHours": 720 * 5,  # 5 bulan
        "filterBy": "Popularity",
        "vocalist": "Vocaloid",
        "maxResults": 100  # Ambil lebih banyak, karena nanti kita filter manual
    }

    response = requests.get(url, params=params)
    data = response.json()

    songs_2025 = []
    for song in data:
        publish_date = song.get("publishDate")
        if publish_date:
            pub_date = datetime.strptime(publish_date, "%Y-%m-%dT%H:%M:%SZ")
            if pub_date.year == 2025 and 1 <= pub_date.month <= 5:
                songs_2025.append(song)

    # Ambil hanya 25 teratas berdasarkan ratingScore
    songs_2025 = sorted(songs_2025, key=lambda x: x.get("ratingScore", 0), reverse=True)[:25]

    # Simpan ke CSV
    with open(filename, mode='w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ["id", "name", "artistString", "vocalist", "publishDate", "ratingScore", "pvServices"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for s in songs_2025:
            writer.writerow({
                "id": s.get("id"),
                "name": s.get("name"),
                "artistString": s.get("artistString"),
                "vocalist": s.get("vocalist"),
                "publishDate": s.get("publishDate"),
                "ratingScore": s.get("ratingScore"),
                "pvServices": s.get("pvServices"),
            })

    print(f"Selesai simpan {len(songs_2025)} lagu ke {filename}")
    return songs_2025

# %% [markdown]
# ## Fetch YouTube URLs from top rated 25 songs

# %%
def get_youtube_urls_from_songs(songs, output_file="songs_with_youtube.csv"):
    results = []

    for song in songs:
        song_id = song["id"]
        song_name = song.get("defaultName", "")
        try:
            url = f"https://vocadb.net/api/songs/{song_id}"
            params = {
                "fields": "PVs"
            }
            response = requests.get(url, params=params)
            if response.status_code != 200:
                print(f"[GAGAL] Fetch detail lagu ID {song_id}")
                continue

            data = response.json()
            pvs = data.get("pvs", [])

            # Ambil semua URL YouTube yang aktif
            youtube_urls = [
                pv.get("url") for pv in pvs
                if pv.get("service", "").lower() == "youtube" and not pv.get("disabled", False)
            ]

            if youtube_urls:
                for yt_url in youtube_urls:
                    results.append({
                        "song_id": song_id,
                        "song_name": song_name,
                        "youtube_url": yt_url
                    })
                print(f"[OK] Lagu ID {song_id} → {len(youtube_urls)} YouTube URL ditemukan.")
            else:
                print(f"[NO YT] Lagu ID {song_id} tidak punya YouTube URL")

            time.sleep(0.5)

        except Exception as e:
            print(f"[ERROR] Exception saat ambil ID {song_id}: {e}")

    # Simpan ke CSV
    with open(output_file, mode="w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=["song_id", "song_name", "youtube_url"])
        writer.writeheader()
        for row in results:
            writer.writerow(row)

    print(f"Selesai simpan {len(results)} URL YouTube ke {output_file}")
    return results

# %%
# Baca csv jadi list
top_songs = []
with open("top_rated_2025.csv", "r", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        top_songs.append({
            "id": int(row["id"]),
            "defaultName": row.get("defaultName", "")
        })

# 2. Ambil YouTube URL-nya
youtube_urls = get_youtube_urls_from_songs(top_songs, output_file="top_25_youtube_urls.csv")
# Out:
# [OK] Lagu ID 734953 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 793121 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 752940 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 749433 → 1 YouTube URL ditemukan.
# [OK] Lagu ID 748682 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 750840 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 747700 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 761077 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 762777 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 776144 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 786030 → 1 YouTube URL ditemukan.
# [OK] Lagu ID 768497 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 749801 → 1 YouTube URL ditemukan.
# [OK] Lagu ID 771172 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 747458 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 788902 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 729113 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 732509 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 753297 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 747843 → 1 YouTube URL ditemukan.
# [OK] Lagu ID 743632 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 788586 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 740379 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 777659 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 741720 → 2 YouTube URL ditemukan.
# Selesai simpan 46 URL YouTube ke top_25_youtube_urls.csv

# %%
from googleapiclient.discovery import build
from urllib.parse import urlparse, parse_qs
import re
# Set ini jika kamu punya YouTube API Key
YOUTUBE_API_KEY = "YOUTUBE_API_KEY"  # Ganti dengan kunci asli

youtube = build("youtube", "v3", developerKey=YOUTUBE_API_KEY)

def fetch_youtube_comments(video_id, max_comments=500):
    comments = []
    next_page_token = None

    try:
        while len(comments) < max_comments:
            response = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=100,  # YouTube API max per page
                pageToken=next_page_token,
                textFormat="plainText"
            ).execute()

            for item in response.get("items", []):
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append({
                    "author": comment.get("authorDisplayName"),
                    "message": comment.get("textDisplay"),
                    "published_at": comment.get("publishedAt"),
                    "like_count": comment.get("likeCount")
                })

                if len(comments) >= max_comments:
                    break

            next_page_token = response.get("nextPageToken")
            if not next_page_token:
                break

    except Exception as e:
        print(f"⚠️ Gagal ambil komentar dari video ID {video_id}: {e}")

    return comments

def extract_video_id(youtube_url):
    try:
        if "youtu.be" in youtube_url:
            return youtube_url.split("/")[-1]
        parsed_url = urlparse(youtube_url)
        query = parse_qs(parsed_url.query)
        return query.get("v", [None])[0]
    except Exception:
        return None

def fetch_youtube_comments_to_csv(song_youtube_data, output_file="yt_comments.csv", max_comments_per_video=500):
    all_comments = []

    for song in song_youtube_data:
        song_id = song["song_id"]
        song_name = song["song_name"]
        youtube_url = song["youtube_url"]
        video_id = extract_video_id(youtube_url)

        if not video_id:
            print(f"[SKIP] Gagal ekstrak video ID dari URL: {youtube_url}")
            continue

        print(f"[YT] Ambil komentar untuk '{song_name}' (ID: {song_id})")
        comments = fetch_youtube_comments(video_id, max_comments=max_comments_per_video)

        for c in comments:
            all_comments.append({
                "song_id": song_id,
                "song_name": song_name,
                "video_id": video_id,
                "author": c["author"],
                "message": c["message"],
                "published_at": c["published_at"],
                "like_count": c["like_count"]
            })

        print(f"[OK] {len(comments)} komentar diambil.")
        time.sleep(1)

    with open(output_file, "w", newline="", encoding="utf-8") as f:
        fieldnames = ["song_id", "song_name", "video_id", "author", "message", "published_at", "like_count"]
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for c in all_comments:
            writer.writerow(c)

    print(f"[DONE] Total {len(all_comments)} komentar disimpan ke '{output_file}'")

# %%
top_songs = []
with open("top_rated_2025.csv", "r", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        top_songs.append({
            "id": int(row["id"]),
            "defaultName": row.get("defaultName", "")
        })

# Langkah 1: Ambil YouTube URLs dari daftar lagu
songs_with_yt = get_youtube_urls_from_songs(top_songs, output_file="songs_with_youtube.csv")

data = pd.read_csv("songs_with_youtube.csv").to_dict(orient="records")
fetch_youtube_comments_to_csv(data, max_comments_per_video=500)
# Out:
# [OK] Lagu ID 734953 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 793121 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 752940 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 749433 → 1 YouTube URL ditemukan.
# [OK] Lagu ID 748682 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 750840 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 747700 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 761077 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 762777 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 776144 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 786030 → 1 YouTube URL ditemukan.
# [OK] Lagu ID 768497 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 749801 → 1 YouTube URL ditemukan.
# [OK] Lagu ID 771172 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 747458 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 788902 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 729113 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 732509 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 753297 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 747843 → 1 YouTube URL ditemukan.
# [OK] Lagu ID 743632 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 788586 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 740379 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 777659 → 2 YouTube URL ditemukan.
# [OK] Lagu ID 741720 → 2 YouTube URL ditemukan.
# Selesai simpan 46 URL YouTube ke songs_with_youtube.csv
# [YT] Ambil komentar untuk 'nan' (ID: 734953)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 734953)
# ⚠️ Gagal ambil komentar dari video ID _JeLNAjjBHw: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_JeLNAjjBHw&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 793121)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 793121)
# ⚠️ Gagal ambil komentar dari video ID Qc8nkGIRft8: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Qc8nkGIRft8&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 752940)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 752940)
# ⚠️ Gagal ambil komentar dari video ID AVIo9K-DrcY: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=AVIo9K-DrcY&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 749433)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 748682)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 748682)
# ⚠️ Gagal ambil komentar dari video ID W2E-J3PvR8w: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=W2E-J3PvR8w&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 750840)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 750840)
# ⚠️ Gagal ambil komentar dari video ID XlZFX_EvUr8: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=XlZFX_EvUr8&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 747700)
# [OK] 230 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 747700)
# ⚠️ Gagal ambil komentar dari video ID cru2vDgnZk4: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=cru2vDgnZk4&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 761077)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 761077)
# ⚠️ Gagal ambil komentar dari video ID SRF8d_wPXSI: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=SRF8d_wPXSI&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 762777)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 762777)
# ⚠️ Gagal ambil komentar dari video ID AL8HMsmvBBI: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=AL8HMsmvBBI&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 776144)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 776144)
# ⚠️ Gagal ambil komentar dari video ID 70gvgaCrA88: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=70gvgaCrA88&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 786030)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 768497)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 768497)
# ⚠️ Gagal ambil komentar dari video ID TWfzTfFBvWo: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=TWfzTfFBvWo&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 749801)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 771172)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 771172)
# ⚠️ Gagal ambil komentar dari video ID xrAAhTXfl5s: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=xrAAhTXfl5s&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 747458)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 747458)
# [OK] 271 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 788902)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 788902)
# ⚠️ Gagal ambil komentar dari video ID zSXpUoW7QJ8: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=zSXpUoW7QJ8&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 729113)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 729113)
# ⚠️ Gagal ambil komentar dari video ID 01eg9BEpUAs: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=01eg9BEpUAs&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 732509)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 732509)
# ⚠️ Gagal ambil komentar dari video ID Givlo4EF2n4: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Givlo4EF2n4&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 753297)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 753297)
# ⚠️ Gagal ambil komentar dari video ID J5tp9a-kBYI: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=J5tp9a-kBYI&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 747843)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 743632)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 743632)
# ⚠️ Gagal ambil komentar dari video ID cW2tAhpvHtE: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=cW2tAhpvHtE&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 788586)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 788586)
# ⚠️ Gagal ambil komentar dari video ID 2XpDyJrQk-4: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=2XpDyJrQk-4&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 740379)
# [OK] 441 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 740379)
# ⚠️ Gagal ambil komentar dari video ID 0KsA4qP3NoY: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0KsA4qP3NoY&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 777659)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 777659)
# ⚠️ Gagal ambil komentar dari video ID tzAgvnABZzo: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=tzAgvnABZzo&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 741720)
# [OK] 500 komentar diambil.
# [YT] Ambil komentar untuk 'nan' (ID: 741720)
# ⚠️ Gagal ambil komentar dari video ID jwoPdVJ1mHw: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=jwoPdVJ1mHw&maxResults=100&textFormat=plainText&key=AIzaSyBM83Ot4LTMeVnztLKqAWNMgoEJpgEFBVo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# [OK] 0 komentar diambil.
# [DONE] Total 12442 komentar disimpan ke 'yt_comments.csv'
